# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import os

cwd = os.getcwd()
print(f"Current Working Directory: {cwd}")
# Out:
# Current Working Directory: C:\Users\mdryh\OneDrive\One Drive\Terahertz Project\Experimental\Scattering

# %% [markdown]
# Sample every 0.2604ps --> 1/sample interval = frequency range.

# %%
def infinite_conductor(theta):
    
    os.chdir(f"{cwd}/infinite_conductor")
    sigma = 0
    stat_distribution = "Smooth"
    freq_lim = 0.3
    
    if theta == 35:
        filename_35 = ['35_theta_20.txt','35_theta_25.txt', '35_theta_30.txt', '35_theta_33.txt','35_theta_35.txt','35_theta_37.txt','35_theta_40.txt','35_theta_45.txt','35_theta_50.txt']
        calibration = 'calibration_infinite_conductor_35.txt'
        range_theta = [20,25,30,33,35,37,40,45,50]
        return sigma,filename_35,stat_distribution,calibration,range_theta,freq_lim
    

def gaussian_10mm(theta):
    
    os.chdir(f"{cwd}/gaussian_0.10mm")
    sigma = 0.10
    stat_distribution = "Gaussian"
    
    if theta == 35:
        filename_35 = ['35_theta_20.txt', '35_theta_25.txt', '35_theta_30.txt','35_theta_32.txt','35_theta_34.txt','35_theta_34.5.txt','35_theta_35.txt','35_theta_35.5.txt','35_theta_36.txt','35_theta_38.txt','35_theta_40.txt','35_theta_45.txt','35_theta_50.txt']
        filename_cst_35 = ['35_0.1_gauss_f_300.txt','35_0.1_gauss_f_450.txt']
        calibration = 'calibration_gaussian_0.10mm_35.txt'
        range_theta = [20,25,30,32,34,34.5,35,35.5,36,38,40,45,50]
        freq_lim = 0.46
        return sigma,filename_35,stat_distribution,calibration,range_theta,freq_lim,filename_cst_35
    elif theta == 40:
        filename_40 = ['40_theta_25.txt', '40_theta_30.txt', '40_theta_35.txt','40_theta_37.txt','40_theta_39.txt','40_theta_39.5.txt','40_theta_40.txt','40_theta_40.5.txt','40_theta_41.txt','40_theta_43.txt','40_theta_45.txt','40_theta_50.txt','40_theta_55.txt'] 
        calibration = 'calibration_gaussian_0.10mm_40.txt'
        range_theta = [25,30,35,37,39,39.5,40,40.5,41,43,45,50,55]
        freq_lim = 0.49
        return sigma,filename_40,stat_distribution,calibration,range_theta,freq_lim
    elif theta == 45:
        filename_45 = ['45_theta_30.txt', '45_theta_35.txt', '45_theta_40.txt','45_theta_42.txt','45_theta_44.txt','45_theta_44.5.txt','45_theta_45.txt','45_theta_45.5.txt','45_theta_46.txt','45_theta_48.txt','45_theta_50.txt','45_theta_55.txt','45_theta_60.txt'] # Poisson
        filename_cst_45 = ['45_0.1_gauss_f_300.txt','45_0.1_gauss_f_450.txt']
        calibration = 'calibration_gaussian_0.10mm_45.txt'
        range_theta = [30,35,40,42,44,44.5,45,45.5,46,48,50,55,60]
        freq_lim = 0.54
        return sigma,filename_45,stat_distribution,calibration,range_theta,freq_lim,filename_cst_45
    elif theta == 50:  
        filename_50 = ['50_theta_35.txt', '50_theta_40.txt', '50_theta_45.txt','50_theta_47.txt','50_theta_49.txt','50_theta_49.5.txt','50_theta_50.txt','50_theta_50.5.txt','50_theta_51.txt','50_theta_53.txt','50_theta_55.txt','50_theta_60.txt','50_theta_65.txt'] # 0.25mm
        calibration = 'calibration_gaussian_0.10mm_50.txt'
        range_theta = [35,40,45,47,49,49.5,50,50.5,51,53,55,60,65]
        freq_lim = 0.59
        return sigma,filename_50,stat_distribution,calibration,range_theta,freq_lim
    elif theta == 55:
        filename_55 = ['55_theta_40.txt', '55_theta_45.txt', '55_theta_50.txt','55_theta_52.txt','55_theta_54.txt','55_theta_54.5.txt','55_theta_55.txt','55_theta_55.5.txt','55_theta_56.txt','55_theta_58.txt','55_theta_60.txt','55_theta_65.txt','55_theta_70.txt']
        filename_cst_55 = ['55_0.1_gauss_f_300.txt','55_0.1_gauss_f_450.txt']
        calibration = 'calibration_gaussian_0.10mm_55.txt'
        range_theta = [40,45,50,52,54,54.5,55,55.5,56,58,60,65,70]
        freq_lim = 0.66
        return sigma,filename_55,stat_distribution,calibration,range_theta,freq_lim,filename_cst_55

    

def gaussian_25mm(theta):
    
    os.chdir(f"{cwd}/gaussian_0.25mm")
    sigma = 0.25
    stat_distribution = "Gaussian"
    freq_lim = 0.3
    
    if theta == 35:
        filename_35 = ['35_theta_20.txt', '35_theta_25.txt', '35_theta_30.txt','35_theta_32.txt','35_theta_34.txt','35_theta_34.5.txt','35_theta_35.txt','35_theta_35.5.txt','35_theta_36.txt','35_theta_38.txt','35_theta_40.txt','35_theta_45.txt','35_theta_50.txt'] 
        filename_cst_35 = ['35_0.25_gauss_f_300.txt','35_0.25_gauss_f_450.txt']
        calibration = 'calibration_gaussian_0.25mm_35.txt'
        range_theta = [20,25,30,32,34,34.5,35,35.5,36,38,40,45,50]
        return sigma,filename_35,stat_distribution,calibration,range_theta,freq_lim,filename_cst_35
    elif theta == 40:
        filename_40 = ['40_theta_25.txt', '40_theta_30.txt', '40_theta_35.txt','40_theta_37.txt','40_theta_39.txt','40_theta_39.5.txt','40_theta_40.txt','40_theta_40.5.txt','40_theta_41.txt','40_theta_43.txt','40_theta_45.txt','40_theta_50.txt','40_theta_55.txt'] 
        calibration = 'calibration_gaussian_0.25mm_40.txt'
        range_theta = [25,30,35,37,39,39.5,40,40.5,41,43,45,50,55]
        return sigma,filename_40,stat_distribution,calibration,range_theta,freq_lim
    elif theta == 45:
        filename_45 = ['45_theta_30.txt', '45_theta_35.txt', '45_theta_40.txt','45_theta_42.txt','45_theta_44.txt','45_theta_44.5.txt','45_theta_45.txt','45_theta_45.5.txt','45_theta_46.txt','45_theta_48.txt','45_theta_50.txt','45_theta_55.txt','45_theta_60.txt'] # Poisson
        filename_cst_45 = ['45_0.25_gauss_f_300.txt','45_0.25_gauss_f_450.txt']
        calibration = 'calibration_gaussian_0.25mm_45.txt'
        range_theta = [30,35,40,42,44,44.5,45,45.5,46,48,50,55,60]
        return sigma,filename_45,stat_distribution,calibration,range_theta,freq_lim,filename_cst_45
    elif theta == 50:  
        filename_50 = ['50_theta_35.txt', '50_theta_40.txt', '50_theta_45.txt','50_theta_47.txt','50_theta_49.txt','50_theta_49.5.txt','50_theta_50.txt','50_theta_50.5.txt','50_theta_51.txt','50_theta_53.txt','50_theta_55.txt','50_theta_60.txt','50_theta_65.txt'] # 0.25mm
        calibration = 'calibration_gaussian_0.25mm_50.txt'
        range_theta = [35,40,45,47,49,49.5,50,50.5,51,53,55,60,65]
        return sigma,filename_50,stat_distribution,calibration,range_theta,freq_lim
    elif theta == 55:
        filename_55 = ['55_theta_40.txt', '55_theta_45.txt', '55_theta_50.txt','55_theta_52.txt','55_theta_54.txt','55_theta_54.5.txt','55_theta_55.txt','55_theta_55.5.txt','55_theta_56.txt','55_theta_58.txt','55_theta_60.txt','55_theta_65.txt','55_theta_70.txt']
        filename_cst_55 = ['55_0.25_gauss_f_300.txt','55_0.25_gauss_f_450.txt']
        calibration = 'calibration_gaussian_0.25mm_55.txt'
        range_theta = [40,45,50,52,54,54.5,55,55.5,56,58,60,65,70]
        return sigma,filename_55,stat_distribution,calibration,range_theta,freq_lim,filename_cst_55



def gaussian_40mm(theta):
    
    os.chdir(f"{cwd}/gaussian_0.40mm")
    sigma = 0.40
    stat_distribution = "Gaussian"
    freq_lim = 0.3
    
    if theta == 35:
        filename_35 = ['35_theta_20.txt', '35_theta_25.txt', '35_theta_30.txt','35_theta_32.txt','35_theta_34.txt','35_theta_34.5.txt','35_theta_35.txt','35_theta_35.5.txt','35_theta_36.txt','35_theta_38.txt','35_theta_40.txt','35_theta_45.txt','35_theta_50.txt'] 
        filename_cst_35 = ['35_0.4_gauss_f_300.txt','35_0.4_gauss_f_450.txt']
        calibration = 'calibration_gaussian_0.40mm_35.txt'
        range_theta = [20,25,30,32,34,34.5,35,35.5,36,38,40,45,50]
        return sigma,filename_35,stat_distribution,calibration,range_theta,freq_lim,filename_cst_35
    elif theta == 40:
        filename_40 = ['40_theta_25.txt', '40_theta_30.txt', '40_theta_35.txt','40_theta_37.txt','40_theta_39.txt','40_theta_39.5.txt','40_theta_40.txt','40_theta_40.5.txt','40_theta_41.txt','40_theta_43.txt','40_theta_45.txt','40_theta_50.txt','40_theta_55.txt'] 
        calibration = 'calibration_gaussian_0.40mm_40.txt'
        range_theta = [25,30,35,37,39,39.5,40,40.5,41,43,45,50,55]
        return sigma,filename_40,stat_distribution,calibration,range_theta,freq_lim
    elif theta == 45:
        filename_45 = ['45_theta_30.txt', '45_theta_35.txt', '45_theta_40.txt','45_theta_42.txt','45_theta_44.txt','45_theta_44.5.txt','45_theta_45.txt','45_theta_45.5.txt','45_theta_46.txt','45_theta_48.txt','45_theta_50.txt','45_theta_55.txt','45_theta_60.txt'] # Poisson
        filename_cst_45 = ['45_0.4_gauss_f_300.txt','45_0.4_gauss_f_450.txt']
        calibration = 'calibration_gaussian_0.40mm_45.txt'
        range_theta = [30,35,40,42,44,44.5,45,45.5,46,48,50,55,60]
        return sigma,filename_45,stat_distribution,calibration,range_theta,freq_lim,filename_cst_45
    elif theta == 50:  
        filename_50 = ['50_theta_35.txt', '50_theta_40.txt', '50_theta_45.txt','50_theta_47.txt','50_theta_49.txt','50_theta_49.5.txt','50_theta_50.txt','50_theta_50.5.txt','50_theta_51.txt','50_theta_53.txt','50_theta_55.txt','50_theta_60.txt','50_theta_65.txt'] # 0.25mm
        calibration = 'calibration_gaussian_0.40mm_50.txt'
        range_theta = [35,40,45,47,49,49.5,50,50.5,51,53,55,60,65]
        return sigma,filename_50,stat_distribution,calibration,range_theta,freq_lim
    elif theta == 55:
        filename_55 = ['55_theta_40.txt', '55_theta_45.txt', '55_theta_50.txt','55_theta_52.txt','55_theta_54.txt','55_theta_54.5.txt','55_theta_55.txt','55_theta_55.5.txt','55_theta_56.txt','55_theta_58.txt','55_theta_60.txt','55_theta_65.txt','55_theta_70.txt']
        filename_cst_55 = ['55_0.4_gauss_f_300.txt','55_0.4_gauss_f_450.txt']
        calibration = 'calibration_gaussian_0.40mm_55.txt'
        range_theta = [40,45,50,52,54,54.5,55,55.5,56,58,60,65,70]
        return sigma,filename_55,stat_distribution,calibration,range_theta,freq_lim,filename_cst_55


def lorentzian_10mm(theta):
    
    os.chdir(f"{cwd}/lorentzian_0.10mm")
    sigma = 0.10
    stat_distribution = "Lorentzian"
    
    if theta == 35:
        filename_35 = ['35_theta_20.txt', '35_theta_25.txt', '35_theta_30.txt','35_theta_32.txt','35_theta_34.txt','35_theta_34.5.txt','35_theta_35.txt','35_theta_35.5.txt','35_theta_36.txt','35_theta_38.txt','35_theta_40.txt','35_theta_45.txt','35_theta_50.txt'] 
        filename_cst_35 = ['35_0.1_lorentz_f_300.txt','35_0.1_lorentz_f_450.txt']
        calibration = 'calibration_lorentzian_0.10mm_35.txt'
        range_theta = [20,25,30,32,34,34.5,35,35.5,36,38,40,45,50]
        freq_lim = 0.46
        return sigma,filename_35,stat_distribution,calibration,range_theta,freq_lim,filename_cst_35
    elif theta == 40:
        filename_40 = ['40_theta_25.txt', '40_theta_30.txt', '40_theta_35.txt','40_theta_37.txt','40_theta_39.txt','40_theta_39.5.txt','40_theta_40.txt','40_theta_40.5.txt','40_theta_41.txt','40_theta_43.txt','40_theta_45.txt','40_theta_50.txt','40_theta_55.txt'] 
        calibration = 'calibration_lorentzian_0.10mm_40.txt'
        range_theta = [25,30,35,37,39,39.5,40,40.5,41,43,45,50,55]
        freq_lim = 0.49
        return sigma,filename_40,stat_distribution,calibration,range_theta,freq_lim
    elif theta == 45:
        filename_45 = ['45_theta_30.txt', '45_theta_35.txt', '45_theta_40.txt','45_theta_42.txt','45_theta_44.txt','45_theta_44.5.txt','45_theta_45.txt','45_theta_45.5.txt','45_theta_46.txt','45_theta_48.txt','45_theta_50.txt','45_theta_55.txt','45_theta_60.txt'] # Poisson
        filename_cst_45 = ['45_0.1_lorentz_f_300.txt','45_0.1_lorentz_f_450.txt']
        calibration = 'calibration_lorentzian_0.10mm_45.txt'
        range_theta = [30,35,40,42,44,44.5,45,45.5,46,48,50,55,60]
        freq_lim = 0.54
        return sigma,filename_45,stat_distribution,calibration,range_theta,freq_lim,filename_cst_45
    elif theta == 50:  
        filename_50 = ['50_theta_35.txt', '50_theta_40.txt', '50_theta_45.txt','50_theta_47.txt','50_theta_49.txt','50_theta_49.5.txt','50_theta_50.txt','50_theta_50.5.txt','50_theta_51.txt','50_theta_53.txt','50_theta_55.txt','50_theta_60.txt','50_theta_65.txt'] # 0.25mm
        calibration = 'calibration_lorentzian_0.10mm_50.txt'
        range_theta = [35,40,45,47,49,49.5,50,50.5,51,53,55,60,65]
        freq_lim = 0.59
        return sigma,filename_50,stat_distribution,calibration,range_theta,freq_lim
    elif theta == 55:
        filename_55 = ['55_theta_40.txt', '55_theta_45.txt', '55_theta_50.txt','55_theta_52.txt','55_theta_54.txt','55_theta_54.5.txt','55_theta_55.txt','55_theta_55.5.txt','55_theta_56.txt','55_theta_58.txt','55_theta_60.txt','55_theta_65.txt','55_theta_70.txt']
        filename_cst_55 = ['55_0.1_lorentz_f_300.txt','55_0.1_lorentz_f_450.txt']
        calibration = 'calibration_lorentzian_0.10mm_55.txt'
        range_theta = [40,45,50,52,54,54.5,55,55.5,56,58,60,65,70]
        freq_lim = 0.66
        return sigma,filename_55,stat_distribution,calibration,range_theta,freq_lim,filename_cst_55


def lorentzian_25mm(theta):
    
    os.chdir(f"{cwd}/lorentzian_0.25mm")
    sigma = 0.25
    stat_distribution = "Lorentzian"
    freq_lim = 0.3
    
    if theta == 35:
        filename_35 = ['35_theta_20.txt', '35_theta_25.txt', '35_theta_30.txt','35_theta_32.txt','35_theta_34.txt','35_theta_34.5.txt','35_theta_35.txt','35_theta_35.5.txt','35_theta_36.txt','35_theta_38.txt','35_theta_40.txt','35_theta_45.txt','35_theta_50.txt'] 
        filename_cst_35 = ['35_0.25_lorentz_f_300.txt','35_0.25_lorentz_f_450.txt']
        calibration = 'calibration_lorentzian_0.25mm_35.txt'
        range_theta = [20,25,30,32,34,34.5,35,35.5,36,38,40,45,50]
        return sigma,filename_35,stat_distribution,calibration,range_theta,freq_lim,filename_cst_35
    elif theta == 40:
        filename_40 = ['40_theta_25.txt', '40_theta_30.txt', '40_theta_35.txt','40_theta_37.txt','40_theta_39.txt','40_theta_39.5.txt','40_theta_40.txt','40_theta_40.5.txt','40_theta_41.txt','40_theta_43.txt','40_theta_45.txt','40_theta_50.txt','40_theta_55.txt'] 
        calibration = 'calibration_lorentzian_0.25mm_40.txt'
        range_theta = [25,30,35,37,39,39.5,40,40.5,41,43,45,50,55]
        return sigma,filename_40,stat_distribution,calibration,range_theta,freq_lim
    elif theta == 45:
        filename_45 = ['45_theta_30.txt', '45_theta_35.txt', '45_theta_40.txt','45_theta_42.txt','45_theta_44.txt','45_theta_44.5.txt','45_theta_45.txt','45_theta_45.5.txt','45_theta_46.txt','45_theta_48.txt','45_theta_50.txt','45_theta_55.txt','45_theta_60.txt'] # Poisson
        filename_cst_45 = ['45_0.25_lorentz_f_300.txt','45_0.25_lorentz_f_450.txt']
        calibration = 'calibration_lorentzian_0.25mm_45.txt'
        range_theta = [30,35,40,42,44,44.5,45,45.5,46,48,50,55,60]
        return sigma,filename_45,stat_distribution,calibration,range_theta,freq_lim,filename_cst_45
    elif theta == 50:  
        filename_50 = ['50_theta_35.txt', '50_theta_40.txt', '50_theta_45.txt','50_theta_47.txt','50_theta_49.txt','50_theta_49.5.txt','50_theta_50.txt','50_theta_50.5.txt','50_theta_51.txt','50_theta_53.txt','50_theta_55.txt','50_theta_60.txt','50_theta_65.txt'] # 0.25mm
        calibration = 'calibration_lorentzian_0.25mm_50.txt'
        range_theta = [35,40,45,47,49,49.5,50,50.5,51,53,55,60,65]
        return sigma,filename_50,stat_distribution,calibration,range_theta,freq_lim
    elif theta == 55:
        filename_55 = ['55_theta_40.txt', '55_theta_45.txt', '55_theta_50.txt','55_theta_52.txt','55_theta_54.txt','55_theta_54.5.txt','55_theta_55.txt','55_theta_55.5.txt','55_theta_56.txt','55_theta_58.txt','55_theta_60.txt','55_theta_65.txt','55_theta_70.txt']
        filename_cst_55 = ['55_0.25_lorentz_f_300.txt','55_0.25_lorentz_f_450.txt']
        calibration = 'calibration_lorentzian_0.25mm_55.txt'
        range_theta = [40,45,50,52,54,54.5,55,55.5,56,58,60,65,70]
        freq_lim = 0.27
        return sigma,filename_55,stat_distribution,calibration,range_theta,freq_lim,filename_cst_55


def lorentzian_40mm(theta):
    
    os.chdir(f"{cwd}/lorentzian_0.40mm")
    sigma = 0.40
    stat_distribution = "Lorentzian"
    freq_lim = 0.3
    
    if theta == 35:
        filename_35 = ['35_theta_20.txt', '35_theta_25.txt', '35_theta_30.txt','35_theta_32.txt','35_theta_34.txt','35_theta_34.5.txt','35_theta_35.txt','35_theta_35.5.txt','35_theta_36.txt','35_theta_38.txt','35_theta_40.txt','35_theta_45.txt','35_theta_50.txt'] 
        filename_cst_35 = ['35_0.4_lorentz_f_300.txt','35_0.4_lorentz_f_450.txt']
        calibration = 'calibration_lorentzian_0.40mm_35.txt'
        range_theta = [20,25,30,32,34,34.5,35,35.5,36,38,40,45,50]
        return sigma,filename_35,stat_distribution,calibration,range_theta,freq_lim,filename_cst_35
    elif theta == 40:
        filename_40 = ['40_theta_25.txt', '40_theta_30.txt', '40_theta_35.txt','40_theta_37.txt','40_theta_39.txt','40_theta_39.5.txt','40_theta_40.txt','40_theta_40.5.txt','40_theta_41.txt','40_theta_43.txt','40_theta_45.txt','40_theta_50.txt','40_theta_55.txt'] 
        calibration = 'calibration_lorentzian_0.40mm_40.txt'
        range_theta = [25,30,35,37,39,39.5,40,40.5,41,43,45,50,55]
        return sigma,filename_40,stat_distribution,calibration,range_theta,freq_lim
    elif theta == 45:
        filename_45 = ['45_theta_30.txt', '45_theta_35.txt', '45_theta_40.txt','45_theta_42.txt','45_theta_44.txt','45_theta_44.5.txt','45_theta_45.txt','45_theta_45.5.txt','45_theta_46.txt','45_theta_48.txt','45_theta_50.txt','45_theta_55.txt','45_theta_60.txt'] # Poisson
        filename_cst_45 = ['45_0.4_lorentz_f_300.txt','45_0.4_lorentz_f_450.txt']
        calibration = 'calibration_lorentzian_0.40mm_45.txt'
        range_theta = [30,35,40,42,44,44.5,45,45.5,46,48,50,55,60]
        return sigma,filename_45,stat_distribution,calibration,range_theta,freq_lim,filename_cst_45
    elif theta == 50:  
        filename_50 = ['50_theta_35.txt', '50_theta_40.txt', '50_theta_45.txt','50_theta_47.txt','50_theta_49.txt','50_theta_49.5.txt','50_theta_50.txt','50_theta_50.5.txt','50_theta_51.txt','50_theta_53.txt','50_theta_55.txt','50_theta_60.txt','50_theta_65.txt'] # 0.25mm
        calibration = 'calibration_lorentzian_0.40mm_50.txt'
        range_theta = [35,40,45,47,49,49.5,50,50.5,51,53,55,60,65]
        return sigma,filename_50,stat_distribution,calibration,range_theta,freq_lim
    elif theta == 55:
        filename_55 = ['55_theta_40.txt', '55_theta_45.txt', '55_theta_50.txt','55_theta_52.txt','55_theta_54.txt','55_theta_54.5.txt','55_theta_55.txt','55_theta_55.5.txt','55_theta_56.txt','55_theta_58.txt','55_theta_60.txt','55_theta_65.txt','55_theta_70.txt']
        filename_cst_55 = ['55_0.4_lorentz_f_300.txt','55_0.4_lorentz_f_450.txt']
        calibration = 'calibration_lorentzian_0.40mm_55.txt'
        range_theta = [40,45,50,52,54,54.5,55,55.5,56,58,60,65,70]
        return sigma,filename_55,stat_distribution,calibration,range_theta,freq_lim,filename_cst_55


def poisson_10mm(theta):
    
    os.chdir(f"{cwd}/poisson_0.10mm")
    sigma = 0.10
    stat_distribution = "Poisson"
    
    
    if theta == 35:
        filename_35 = ['35_theta_20.txt', '35_theta_25.txt', '35_theta_30.txt','35_theta_32.txt','35_theta_34.txt','35_theta_34.5.txt','35_theta_35.txt','35_theta_35.5.txt','35_theta_36.txt','35_theta_38.txt','35_theta_40.txt','35_theta_45.txt','35_theta_50.txt'] 
        filename_cst_35 = ['35_0.1_pois_f_300.txt','35_0.1_pois_f_450.txt']
        calibration = 'calibration_poisson_0.10mm_35.txt'
        range_theta = [20,25,30,32,34,34.5,35,35.5,36,38,40,45,50]
        freq_lim = 0.46
        return sigma,filename_35,stat_distribution,calibration,range_theta,freq_lim,filename_cst_35
    elif theta == 40:
        filename_40 = ['40_theta_25.txt', '40_theta_30.txt', '40_theta_35.txt','40_theta_37.txt','40_theta_39.txt','40_theta_39.5.txt','40_theta_40.txt','40_theta_40.5.txt','40_theta_41.txt','40_theta_43.txt','40_theta_45.txt','40_theta_50.txt','40_theta_55.txt'] 
        calibration = 'calibration_poisson_0.10mm_40.txt'
        range_theta = [25,30,35,37,39,39.5,40,40.5,41,43,45,50,55]
        freq_lim = 0.49
        return sigma,filename_40,stat_distribution,calibration,range_theta,freq_lim
    elif theta == 45:
        filename_45 = ['45_theta_30.txt', '45_theta_35.txt', '45_theta_40.txt','45_theta_42.txt','45_theta_44.txt','45_theta_44.5.txt','45_theta_45.txt','45_theta_45.5.txt','45_theta_46.txt','45_theta_48.txt','45_theta_50.txt','45_theta_55.txt','45_theta_60.txt'] # Poisson
        filename_cst_45 = ['45_0.1_pois_f_300.txt','45_0.1_pois_f_450.txt']
        calibration = 'calibration_poisson_0.10mm_45.txt'
        range_theta = [30,35,40,42,44,44.5,45,45.5,46,48,50,55,60]
        freq_lim = 0.54
        return sigma,filename_45,stat_distribution,calibration,range_theta,freq_lim,filename_cst_45
    elif theta == 50:  
        filename_50 = ['50_theta_35.txt', '50_theta_40.txt', '50_theta_45.txt','50_theta_47.txt','50_theta_49.txt','50_theta_49.5.txt','50_theta_50.txt','50_theta_50.5.txt','50_theta_51.txt','50_theta_53.txt','50_theta_55.txt','50_theta_60.txt','50_theta_65.txt'] # 0.25mm
        calibration = 'calibration_poisson_0.10mm_50.txt'
        range_theta = [35,40,45,47,49,49.5,50,50.5,51,53,55,60,65]
        freq_lim = 0.59
        return sigma,filename_50,stat_distribution,calibration,range_theta,freq_lim
    elif theta == 55:
        filename_55 = ['55_theta_40.txt', '55_theta_45.txt', '55_theta_50.txt','55_theta_52.txt','55_theta_54.txt','55_theta_54.5.txt','55_theta_55.txt','55_theta_55.5.txt','55_theta_56.txt','55_theta_58.txt','55_theta_60.txt','55_theta_65.txt','55_theta_70.txt']
        filename_cst_55 = ['55_0.1_pois_f_300.txt','55_0.1_pois_f_450.txt']
        calibration = 'calibration_poisson_0.10mm_55.txt'
        range_theta = [40,45,50,52,54,54.5,55,55.5,56,58,60,65,70]
        freq_lim = 0.66
        return sigma,filename_55,stat_distribution,calibration,range_theta,freq_lim,filename_cst_55


def poisson_25mm(theta):
    
    os.chdir(f"{cwd}/poisson_0.25mm")
    sigma = 0.25
    stat_distribution = "Poisson"
    freq_lim = 0.3
    
    if theta == 35:
        filename_35 = ['35_theta_20.txt', '35_theta_25.txt', '35_theta_30.txt','35_theta_32.txt','35_theta_34.txt','35_theta_34.5.txt','35_theta_35.txt','35_theta_35.5.txt','35_theta_36.txt','35_theta_38.txt','35_theta_40.txt','35_theta_45.txt','35_theta_50.txt'] 
        filename_cst_35 = ['35_0.25_pois_f_300.txt','35_0.25_pois_f_450.txt']
        calibration = 'calibration_poisson_0.25mm_35.txt'
        range_theta = [20,25,30,32,34,34.5,35,35.5,36,38,40,45,50]
        return sigma,filename_35,stat_distribution,calibration,range_theta,freq_lim,filename_cst_35
    elif theta == 40:
        filename_40 = ['40_theta_25.txt', '40_theta_30.txt', '40_theta_35.txt','40_theta_37.txt','40_theta_39.txt','40_theta_39.5.txt','40_theta_40.txt','40_theta_40.5.txt','40_theta_41.txt','40_theta_43.txt','40_theta_45.txt','40_theta_50.txt','40_theta_55.txt'] 
        calibration = 'calibration_poisson_0.25mm_40.txt'
        range_theta = [25,30,35,37,39,39.5,40,40.5,41,43,45,50,55]
        return sigma,filename_40,stat_distribution,calibration,range_theta,freq_lim
    elif theta == 45:
        filename_45 = ['45_theta_30.txt', '45_theta_35.txt', '45_theta_40.txt','45_theta_42.txt','45_theta_44.txt','45_theta_44.5.txt','45_theta_45.txt','45_theta_45.5.txt','45_theta_46.txt','45_theta_48.txt','45_theta_50.txt','45_theta_55.txt','45_theta_60.txt'] # Poisson
        filename_cst_45 = ['45_0.25_pois_f_300.txt','45_0.25_pois_f_450.txt']
        calibration = 'calibration_poisson_0.25mm_45.txt'
        range_theta = [30,35,40,42,44,44.5,45,45.5,46,48,50,55,60]
        return sigma,filename_45,stat_distribution,calibration,range_theta,freq_lim,filename_cst_45
    elif theta == 50:  
        filename_50 = ['50_theta_35.txt', '50_theta_40.txt', '50_theta_45.txt','50_theta_47.txt','50_theta_49.txt','50_theta_49.5.txt','50_theta_50.txt','50_theta_50.5.txt','50_theta_51.txt','50_theta_53.txt','50_theta_55.txt','50_theta_60.txt','50_theta_65.txt'] # 0.25mm
        calibration = 'calibration_poisson_0.25mm_50.txt'
        range_theta = [35,40,45,47,49,49.5,50,50.5,51,53,55,60,65]
        return sigma,filename_50,stat_distribution,calibration,range_theta,freq_lim
    elif theta == 55:
        filename_55 = ['55_theta_40.txt', '55_theta_45.txt', '55_theta_50.txt','55_theta_52.txt','55_theta_54.txt','55_theta_54.5.txt','55_theta_55.txt','55_theta_55.5.txt','55_theta_56.txt','55_theta_58.txt','55_theta_60.txt','55_theta_65.txt','55_theta_70.txt']
        filename_cst_55 = ['55_0.25_pois_f_300.txt','55_0.25_pois_f_450.txt']
        calibration = 'calibration_poisson_0.25mm_55.txt'
        range_theta = [40,45,50,52,54,54.5,55,55.5,56,58,60,65,70]
        freq_lim = 0.27
        return sigma,filename_55,stat_distribution,calibration,range_theta,freq_lim,filename_cst_55

def poisson_40mm(theta):
    
    os.chdir(f"{cwd}/poisson_0.40mm")
    sigma = 0.40
    stat_distribution = "Poisson"
    freq_lim = 0.3
    
    if theta == 35:
        filename_35 = ['35_theta_20.txt', '35_theta_25.txt', '35_theta_30.txt','35_theta_32.txt','35_theta_34.txt','35_theta_34.5.txt','35_theta_35.txt','35_theta_35.5.txt','35_theta_36.txt','35_theta_38.txt','35_theta_40.txt','35_theta_45.txt','35_theta_50.txt'] 
        filename_cst_35 = ['35_0.4_pois_f_300.txt','35_0.4_pois_f_450.txt']
        calibration = 'calibration_poisson_0.40mm_35.txt'
        range_theta = [20,25,30,32,34,34.5,35,35.5,36,38,40,45,50]
        return sigma,filename_35,stat_distribution,calibration,range_theta,freq_lim,filename_cst_35
    elif theta == 40:
        filename_40 = ['40_theta_25.txt', '40_theta_30.txt', '40_theta_35.txt','40_theta_37.txt','40_theta_39.txt','40_theta_39.5.txt','40_theta_40.txt','40_theta_40.5.txt','40_theta_41.txt','40_theta_43.txt','40_theta_45.txt','40_theta_50.txt','40_theta_55.txt'] 
        calibration = 'calibration_poisson_0.40mm_40.txt'
        range_theta = [25,30,35,37,39,39.5,40,40.5,41,43,45,50,55]
        return sigma,filename_40,stat_distribution,calibration,range_theta,freq_lim
    elif theta == 45:
        filename_45 = ['45_theta_30.txt', '45_theta_35.txt', '45_theta_40.txt','45_theta_42.txt','45_theta_44.txt','45_theta_44.5.txt','45_theta_45.txt','45_theta_45.5.txt','45_theta_46.txt','45_theta_48.txt','45_theta_50.txt','45_theta_55.txt','45_theta_60.txt'] # Poisson
        filename_cst_45 = ['45_0.4_pois_f_300.txt','45_0.4_pois_f_450.txt']
        calibration = 'calibration_poisson_0.40mm_45.txt'
        range_theta = [30,35,40,42,44,44.5,45,45.5,46,48,50,55,60]
        return sigma,filename_45,stat_distribution,calibration,range_theta,freq_lim,filename_cst_45
    elif theta == 50:  
        filename_50 = ['50_theta_35.txt', '50_theta_40.txt', '50_theta_45.txt','50_theta_47.txt','50_theta_49.txt','50_theta_49.5.txt','50_theta_50.txt','50_theta_50.5.txt','50_theta_51.txt','50_theta_53.txt','50_theta_55.txt','50_theta_60.txt','50_theta_65.txt'] # 0.25mm
        calibration = 'calibration_poisson_0.40mm_50.txt'
        range_theta = [35,40,45,47,49,49.5,50,50.5,51,53,55,60,65]
        return sigma,filename_50,stat_distribution,calibration,range_theta,freq_lim
    elif theta == 55:
        filename_55 = ['55_theta_40.txt', '55_theta_45.txt', '55_theta_50.txt','55_theta_52.txt','55_theta_54.txt','55_theta_54.5.txt','55_theta_55.txt','55_theta_55.5.txt','55_theta_56.txt','55_theta_58.txt','55_theta_60.txt','55_theta_65.txt','55_theta_70.txt']
        filename_cst_55 = ['55_0.4_pois_f_300.txt','55_0.4_pois_f_450.txt']
        calibration = 'calibration_poisson_0.40mm_55.txt'
        range_theta = [40,45,50,52,54,54.5,55,55.5,56,58,60,65,70]
        return sigma,filename_55,stat_distribution,calibration,range_theta,freq_lim,filename_cst_55


# first number=incident, second number=scattered
# Do each incident angle separately

# %%
theta = 55                                        # incident angle of choice

sigma = gaussian_40mm(theta=theta)[0]
filenames = gaussian_40mm(theta=theta)[1]            # selection of function to use (gauss/lorentz/poiss)
specular = gaussian_40mm(theta=theta)[1][4]         # generic data set, needed for the shape, to calculate step freq.
Stat_distribution = gaussian_40mm(theta=theta)[2]    # only these need to be changed
data = gaussian_40mm(theta=theta)[3]
theta_range = gaussian_40mm(theta=theta)[4]
freq_lim = gaussian_40mm(theta=theta)[5]

data_cal = np.loadtxt(data)
data1_spec = np.loadtxt(specular)


l = data1_spec.shape[0]
#win=np.hanning(l)

t = data_cal[:,0]
t_int = (t[1]-t[0])*1e-12
f_lim = 1/t_int                                     # calculates step frequency for the freq. linspace
#print(f_lim)
f = np.linspace(0, f_lim, l)
print(f_lim)
lamb = 3e8/f

ycal = data_cal[:,1]
ycal = ycal[:l]
#print(ycal.shape)
cal_ft = np.fft.fft(ycal)
#print(np.abs(cal_ft))


range_theta = np.array(theta_range)                 # ranges for annotations; may need to be changed to fit them on better
theta_max = np.max(theta_range)-2
freq_min = freq_lim+0.02


Mean_Scat_p = np.zeros([len(filenames), l])
n=0

for file in filenames:
    
    data = np.loadtxt(file)
    y = data[:,1]
    print(file)
    
    if y.shape[0] > 877:                            # loads in each file called in from the definition
        y = y[:l]                                   # normalises using the calibration taken
        #print(y.shape)                             
                                                    # fourier transforms each file for E-field as a function of frequency
    ft = np.fft.fft(y)                              # converts scattering E-field measured into mean scattered power
    norm_ft = np.abs(ft)/np.abs(cal_ft)
    #print(norm_ft)
    
    Mean_Scat_p[n] = 20*np.log10(np.abs(norm_ft))
    #print(data.shape)
    #print(Mean_Scat_p)
    n+=1

Mean_Scat_p = np.flip(Mean_Scat_p, axis=0) 
Mean_Scat_p[Mean_Scat_p > 0] = 0                    # limits on max/ min power set  
Mean_Scat_p[Mean_Scat_p < -60] = -60                # shouldn't be positive unless theres an issue with data

#print(Mean_Scat_p.shape)
#print(Mean_Scat_p)
#df = pd.DataFrame(Mean_Scat_p)
#df.to_csv('data.csv', index = False)
print(freq_lim)
# Out:
# 6402048655569.782
# 55_theta_40.txt
# 55_theta_45.txt
# 55_theta_50.txt
# 55_theta_52.txt
# 55_theta_54.txt
# 55_theta_54.5.txt
# 55_theta_55.txt
# 55_theta_55.5.txt
# 55_theta_56.txt
# 55_theta_58.txt
# 55_theta_60.txt
# 55_theta_65.txt
# 55_theta_70.txt
# 0.3
# C:\Users\mdryh\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: RuntimeWarning: divide by zero encountered in true_divide

# %%
x = data_cal[:,0]
y = data_cal[:,1]
x1 = data1_spec[:,0]
y1 = data1_spec[:,1]

# %%
print(len(x))
print(len(x1))                           # all shapes should match otherwise change the shape of the freq. linspace
print(len(y))
print(len(y1))
# Out:
# 334
# 334
# 334
# 334

# %%
plt.plot(x1,y1*40,'b')                   # scaling factor used purely for comparison on graph
#plt.plot(x,y,'r')                        # time domain of specular sample
#plt.show()
plt.xlabel('Time (ps)', fontsize=12)
plt.ylabel('Electric Field (a.u.)', fontsize=12)
#plt.annotate('A', (50,4), fontsize=20,color='black')

#plt.savefig(f'../../Graphs/Experimental_scattering/calibration.png', dpi=1000)
# Out:
# Text(0, 0.5, 'Electric Field (a.u.)')

# %%
#transmission_data = np.loadtxt('transmission_data_with_FP.txt')
#a = transmission_data[:,0]
#b = transmission_data[:,1]
#plt.plot(a,b,'b')                   # scaling factor used purely for comparison on graph
#plt.plot(x,y,'r')                        # time domain of specular sample
#plt.show()
#plt.xlabel('Time (ps)', fontsize=12)
#plt.ylabel('Electric Field (a.u.)', fontsize=12)
#plt.annotate('A', (50,4), fontsize=20,color='black')

#plt.savefig(f'../../Graphs/Experimental_scattering/calibration.png', dpi=1000)

# %%
ft1 = np.fft.fft(y1)
ft = np.fft.fft(y)
frequ = np.linspace(0, 1/(x[1]), 334)
#print(frequ)
print(1/(x[1]))
print(np.max(np.abs(ft1)))
# Out:
# 6.402048655569782
# 0.2518357277977648

# %%
a = 20*np.log10(np.abs(ft1)/np.max(np.abs(ft1)))
b = 20*np.log10(np.abs(ft)/np.max(np.abs(ft1)))
#plt.plot(frequ,a,'y')
plt.plot(frequ,b,'r')                                # plot of fourier transformed specular data
#plt.plot(frequ,b-a,'g')                              # check against Teramat to see if its the same
plt.xlim(0,2)
plt.xlabel('Frequency (THz)', fontsize=12)
plt.ylabel('Electric Field (a.u.)', fontsize=12)
plt.annotate('B', (1.85,10.5), fontsize=20,color='black')

#plt.savefig(f'../../Graphs/Experimental_scattering/calibration_ft.png', dpi=1000)
# Out:
# Text(1.85, 10.5, 'B')

# %%
'''Aesthetic Colour map of comparison between scattered angle and frequency using just experimental'''

Mean_Scat_P = np.zeros((len(theta_range),len(f)))
Mean_Scat_P[:13,:] = Mean_Scat_p
fig, ax1 = plt.subplots(figsize=(24,10))
levels = np.linspace(-60,0, 61)                            # changing the levels changes the number of contours

h =plt.contourf(f*1e-12,range_theta,Mean_Scat_P, levels=levels, cmap='jet', vmin=-59.9999999)

ax1.set_xlabel('Frequency (THz)', fontsize=34)
ax1.set_ylabel('Scattered Elevation Angle ($\degree$)', fontsize=34)
ax1.tick_params(axis='both', which='major', labelsize=28)

ax2 = ax1.twiny()
ax2.set_xlabel('Wavelength (mm)', fontsize=34)
ax2.set_xticklabels([1,0.75,0.6,0.5,0.43,0.38,0.33,0.3])  # corresponding wavelengths
ax2.tick_params(axis='both', which='major', labelsize=28)

ax1.set_title(f'Measured Power when Incident at {theta}$\degree$', fontsize=40, y=1.12)

cbar = plt.colorbar(label = 'Mean Scattered Power (dB)')
cbar.set_ticks([-60,-50,-40,-30,-20,-10,0])
cbar.ax.tick_params(labelsize=28)
cbar.set_label(label = 'Mean Scattered Power (dB)',size=34)
cbar.set_ticklabels(['<-60',-50,-40,-30,-20,-10,0])
ax1.set_xlim(freq_lim,1)
ax2.set_xlim(freq_lim,1)                                              # uses Rayleigh Roughness Criterion

plt.annotate(f'$\sigma$={sigma}mm', (freq_min,theta_max), fontsize=30,color='white')
plt.annotate(f'{Stat_distribution}',(freq_min,theta_max-2), fontsize=30,color='white')

plt.savefig(f'../../Graphs/Experimental_scattering/{Stat_distribution}_{sigma}mm_{theta}_{freq_lim}THz.png', dpi=1000, bbox_inches = 'tight')

# %%
'''Aesthetic Colour map of comparison between scattered angle and frequency using just experimental'''

Mean_Scat_P = np.zeros((len(theta_range),len(f)))
Mean_Scat_P[:13,:] = Mean_Scat_p
fig, ax1 = plt.subplots(figsize=(24,10))
levels = np.linspace(-60,0, 61)                            # changing the levels changes the number of contours

h =plt.contourf(f*1e-12,range_theta,Mean_Scat_P, levels=levels, cmap='jet', vmin=-59.9999999)

ax1.set_xlabel('Frequency (THz)', fontsize=34)
ax1.set_ylabel('Scattered Elevation Angle ($\degree$)', fontsize=34)
ax1.tick_params(axis='both', which='major', labelsize=28)

ax2 = ax1.twiny()
ax2.set_xlabel('Wavelength (mm)', fontsize=34)
ax2.set_xticklabels([0.6,0.5,0.43,0.38,0.33,0.3])  # corresponding wavelengths
ax2.tick_params(axis='both', which='major', labelsize=28)

ax1.set_title(f'Measured Power when Incident at {theta}$\degree$', fontsize=40, y=1.12)

cbar = plt.colorbar(label = 'Mean Scattered Power (dB)')
cbar.set_ticks([-60,-50,-40,-30,-20,-10,0])
cbar.ax.tick_params(labelsize=28)
cbar.set_label(label = 'Mean Scattered Power (dB)',size=34)
cbar.set_ticklabels(['<-60',-50,-40,-30,-20,-10,0])
ax1.set_xlim(0.3,1)
ax2.set_xlim(0.3,1)                                         

plt.annotate(f'$\sigma$={sigma}mm', (0.32,theta_max), fontsize=30,color='white')
plt.annotate(f'{Stat_distribution}',(0.32,theta_max-2), fontsize=30,color='white')

#plt.savefig(f'../../Graphs/Experimental_scattering/{Stat_distribution}_{sigma}mm_{theta}.png', dpi=1000, bbox_inches = 'tight')
# Out:
# Text(0.32, 66.0, 'Gaussian')

# %%
'''Colour map of comparison between scattered angle and frequency using just experimental, with linear light levels'''

Mean_Scat_P = np.zeros((len(theta_range),len(f)))
Mean_Scat_P[:13,:] = Mean_Scat_p
fig, ax1 = plt.subplots(figsize=(24,10))
levels = np.linspace(-60,0, 61)

h =plt.contourf(f*1e-12,range_theta,Mean_Scat_P, levels=levels, cmap='inferno', vmin=-59.9999999)#changing the levels changes the number of contours

ax1.set_xlabel('Frequency (THz)', fontsize=34)
ax1.set_ylabel('Scattered Elevation Angle ($\degree$)', fontsize=34)
ax1.tick_params(axis='both', which='major', labelsize=28)

ax2 = ax1.twiny()
ax2.set_xlabel('Wavelength (mm)', fontsize=34)
ax2.set_xticklabels([0.6,0.5,0.43,0.38,0.33,0.3])  # corresponding wavelengths

ax2.tick_params(axis='both', which='major', labelsize=28)

ax1.set_title(f'Measured Power when Incident at {theta}$\degree$', fontsize=40, y=1.12)

cbar = plt.colorbar(label = 'Mean Scattered Power (dB)')
cbar.set_ticks([-60,-50,-40,-30,-20,-10,0])
cbar.ax.tick_params(labelsize=28)
cbar.set_label(label = 'Mean Scattered Power (dB)',size=34)
cbar.set_ticklabels(['<-60',-50,-40,-30,-20,-10,0])
ax1.set_xlim(0.3,1)
ax2.set_xlim(0.3,1)

plt.annotate(f'$\sigma$={sigma}mm', (0.32,theta_max), fontsize=30,color='white')
plt.annotate(f'{Stat_distribution}',(0.32,theta_max-2), fontsize=30,color='white')

#plt.savefig(f'../../Graphs/Experimental_scattering/{Stat_distribution}_{sigma}mm_{theta}_uniform_light.png', dpi=1000, bbox_inches = 'tight')
# Out:
# Text(0.32, 66.0, 'Gaussian')

# %%
'''Colour map of comparison between scattered angle and frequency using just experimental, with linear light levels'''

Mean_Scat_P = np.zeros((len(theta_range),len(f)))
Mean_Scat_P[:13,:] = Mean_Scat_p
fig, ax1 = plt.subplots(figsize=(24,10))
levels = np.linspace(-60,0, 61)

h =plt.contourf(f*1e-12,range_theta,Mean_Scat_P, levels=levels, cmap='inferno', vmin=-59.9999999)#changing the levels changes the number of contours

ax1.set_xlabel('Frequency (THz)', fontsize=34)
ax1.set_ylabel('Scattered Elevation Angle ($\degree$)', fontsize=34)
ax1.tick_params(axis='both', which='major', labelsize=28)

ax2 = ax1.twiny()
ax2.set_xlabel('Wavelength (mm)', fontsize=34)
ax2.set_xticklabels([0.6,0.5,0.43,0.38,0.33,0.3])  # corresponding wavelengths

ax2.tick_params(axis='both', which='major', labelsize=28)

ax1.set_title(f'Measured Power when Incident at {theta}$\degree$', fontsize=40, y=1.12)

cbar = plt.colorbar(label = 'Mean Scattered Power (dB)')
cbar.set_ticks([-60,-50,-40,-30,-20,-10,0])
cbar.ax.tick_params(labelsize=28)
cbar.set_label(label = 'Mean Scattered Power (dB)',size=34)
cbar.set_ticklabels(['<-60',-50,-40,-30,-20,-10,0])
ax1.set_xlim(freq_lim,1)
ax2.set_xlim(freq_lim,1)                                              # uses Rayleigh roughness criterion

plt.annotate(f'$\sigma$={sigma}mm', (freq_min,theta_max), fontsize=30,color='white')
plt.annotate(f'{Stat_distribution}',(freq_min,theta_max-2), fontsize=30,color='white')

#plt.savefig(f'../../Graphs/Experimental_scattering/{Stat_distribution}_{sigma}mm_{theta}_uniform_light_{freq_lim}THz.png', dpi=1000, bbox_inches = 'tight')
# Out:
# Text(0.32, 66.0, 'Gaussian')

# %%
os.chdir(f"../")
cwd = os.getcwd()

theta_i = 55

j = gaussian_40mm(theta=theta_i)[1]
sigma = gaussian_40mm(theta=theta_i)[0]
data_1 = gaussian_40mm(theta=theta_i)[3]
range_theta_i = gaussian_40mm(theta=theta_i)[4]
cst_gauss = gaussian_40mm(theta=theta_i)[6]

gauss_cst_data_300 = np.loadtxt(cst_gauss[0], skiprows = 2)
gauss_cst_theta_data_300 = gauss_cst_data_300[:,0]
gauss_cst_rcs_data_300 = gauss_cst_data_300[:,2] / (np.pi)              # where r = 0.5m

gauss_cst_data_450 = np.loadtxt(cst_gauss[1], skiprows = 2)
gauss_cst_theta_data_450 = gauss_cst_data_450[:,0]
gauss_cst_rcs_data_450 = gauss_cst_data_450[:,2] / (np.pi)              # where r = 0.5m

data_cal_1 = np.loadtxt(data_1)
t = data_cal_1[:,0]
t_int = (t[1]-t[0])*1e-12
f_lim = 1/t_int                                     # calculates step frequency for the freq. linspace
#print(f_lim)
f = np.linspace(0, f_lim, l)
print(f_lim)
lamb = 3e8/f

ycal_1 = data_cal_1[:,1]
ycal_1 = ycal_1[:l]
#print(ycal_1.shape)
cal_ft = np.fft.fft(ycal_1)
#print(np.abs(cal_ft_1))


Mean_Scat_p_1 = np.zeros([len(j), l])
n=0

for file in j:
    
    data = np.loadtxt(file)
    y = data[:,1]
    #print(file)
    
    if y.shape[0] > 877:                            # loads in each file called in from the definition
        y = y[:l]                                   # normalises using the calibration taken
        #print(y.shape)                             
                                                    # fourier transforms each file for E-field as a function of frequency
    ft = np.fft.fft(y)                              # converts scattering E-field measured into mean scattered power
    norm_ft = np.abs(ft)/np.abs(cal_ft)
    #print(norm_ft)
    
    Mean_Scat_p_1[n] = 20*np.log10(np.abs(norm_ft))
    #print(data.shape)
    #print(Mean_Scat_p)
    n+=1

Mean_Scat_p_1 = np.flip(Mean_Scat_p_1, axis=0) 
Mean_Scat_p_1[Mean_Scat_p_1 > 0] = 0                    # limits on max/ min power set  
Mean_Scat_p_1[Mean_Scat_p_1 < -60] = -60                # shouldn't be positive unless theres an issue with data

Mean_Scat_P_1 = np.zeros([13,len(f)])
Mean_Scat_P_1[:13,:] = Mean_Scat_p_1



cwd = os.getcwd()
#print(f"Current Working Directory: {cwd}")

#print(Mean_Scat_P_1)
# Out:
# 6402048655569.782
# C:\Users\mdryh\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: RuntimeWarning: divide by zero encountered in true_divide

# %%
os.chdir(f"../")
cwd = os.getcwd()

k = poisson_40mm(theta=theta_i)[1]
data_1 = poisson_40mm(theta=theta_i)[3]
range_theta_i = poisson_40mm(theta=theta_i)[4]
cst_poiss = poisson_40mm(theta=theta_i)[6]

poiss_cst_data_300 = np.loadtxt(cst_poiss[0], skiprows = 2)
poiss_cst_theta_data_300 = poiss_cst_data_300[:,0]
poiss_cst_rcs_data_300 = poiss_cst_data_300[:,2] / (np.pi)              # where r = 0.5m

poiss_cst_data_450 = np.loadtxt(cst_poiss[1], skiprows = 2)
poiss_cst_theta_data_450 = poiss_cst_data_450[:,0]
poiss_cst_rcs_data_450 = poiss_cst_data_450[:,2] / (np.pi)              # where r = 0.5m

Mean_Scat_p_2 = np.zeros([len(k), l])
n=0

for file in k:
    
    data = np.loadtxt(file)
    y = data[:,1]
    #print(file)
    
    if y.shape[0] > 877:                            # loads in each file called in from the definition
        y = y[:l]                                   # normalises using the calibration taken
        #print(y.shape)                             
                                                    # fourier transforms each file for E-field as a function of frequency
    ft = np.fft.fft(y)                              # converts scattering E-field measured into mean scattered power
    norm_ft = np.abs(ft)/np.abs(cal_ft)
    #print(norm_ft)
    
    Mean_Scat_p_2[n] = 20*np.log10(np.abs(norm_ft))
    #print(data.shape)
    #print(Mean_Scat_p)
    n+=1

Mean_Scat_p_2 = np.flip(Mean_Scat_p_2, axis=0) 
Mean_Scat_p_2[Mean_Scat_p_2 > 0] = 0                    # limits on max/ min power set  
Mean_Scat_p_2[Mean_Scat_p_2 < -60] = -60                # shouldn't be positive unless theres an issue with data

Mean_Scat_P_2 = np.zeros([13,len(f)])
Mean_Scat_P_2[:13,:] = Mean_Scat_p_2

#print(Mean_Scat_P_2)

# %%
freq = 0.3

diff = (f*1e-12) - freq
diff = np.abs(diff)
ind = np.argmin(diff)                               # average scattered power at the desired frequency                        
print(ind)                                          # only takes into account no. of scattered angles measured at

#plt.annotate(f'$\sigma$={sigma}THz', (theta_max-2.5,maximum-0.8), fontsize=10,color='black')

power_1 = Mean_Scat_P_1[:, ind]
plt.plot(range_theta_i, power_1, color='blue')

plt.plot(gauss_cst_theta_data_300, gauss_cst_rcs_data_300, color='blue',linestyle='--')

power_2 = Mean_Scat_P_2[:, ind]
plt.plot(range_theta_i, power_2,color='orange')

plt.plot(poiss_cst_theta_data_300, poiss_cst_rcs_data_300, color='orange',linestyle='--')

#power_3 = Mean_Scat_P_3[:, ind]
#plt.plot(range_theta_i, power_3,color='green')

#plt.plot(lorentz_cst_theta_data_300, lorentz_cst_rcs_data_300, color='green',linestyle='--')
plt.xlim(min(range_theta_i),max(range_theta_i))

plt.legend(['Gaussian','Gaussian CST','Poisson','Poisson CST'], fontsize=8)
plt.xlabel('Scattered Elevation Angle ($\degree$)', fontsize=11)
plt.ylabel('Mean Scattered Power (dB)', fontsize=11)
plt.title(f'Measured Power when Incident at {freq}THz at {theta_i}$\degree$ for $\sigma$={sigma}mm', fontsize=12)
plt.tick_params(axis='both', which='major', labelsize=11)
plt.axvline(theta_i, linestyle=':', color='k')

#plt.savefig(f'../../Graphs/Experimental_scattering/{freq}THz_{sigma}mm_{theta_i}_power_avg_w_cst.png', dpi=1000)
# Out:
# 16

# %%
freq = 0.45

diff = (f*1e-12) - freq
diff = np.abs(diff)
ind = np.argmin(diff)                               # average scattered power at the desired frequency                        
print(ind)                                          # only takes into account no. of scattered angles measured at

#plt.annotate(f'$\sigma$={sigma}mm', (theta_max-2.5,maximum-0.8), fontsize=10,color='black')

power_1 = Mean_Scat_P_1[:, ind]
plt.plot(range_theta_i, power_1, color='blue')

plt.plot(gauss_cst_theta_data_450, gauss_cst_rcs_data_450, color='blue',linestyle='--')

power_2 = Mean_Scat_P_2[:, ind]
plt.plot(range_theta_i, power_2,color='orange')

plt.plot(poiss_cst_theta_data_450, poiss_cst_rcs_data_450, color='orange',linestyle='--')

#power_3 = Mean_Scat_P_3[:, ind]
#plt.plot(range_theta_i, power_3,color='green')

#plt.plot(lorentz_cst_theta_data_450, lorentz_cst_rcs_data_450, color='green',linestyle='--')
plt.xlim(min(range_theta_i),max(range_theta_i))

plt.legend(['Gaussian','Gaussian CST','Poisson','Poisson CST'], fontsize=8)
plt.xlabel('Scattered Elevation Angle ($\degree$)', fontsize=11)
plt.ylabel('Mean Scattered Power (dB)', fontsize=11)
plt.title(f'Measured Power when Incident at {freq}THz at {theta_i}$\degree$ for $\sigma$={sigma}mm', fontsize=12)
plt.tick_params(axis='both', which='major', labelsize=11)
plt.axvline(theta_i, linestyle=':', color='k')

#plt.savefig(f'../../Graphs/Experimental_scattering/{freq}THz_{sigma}mm_{theta_i}_power_avg_w_cst.png', dpi=1000)
# Out:
# 23

# %%
avg_p = []
for i in range(0,13):
    avg = np.mean(Mean_Scat_P[i,:])                           # average scattered power at all frequencies
    avg_p.append(avg)                                         # only takes into account no. of scattered angles measured at
    
print(avg_p)
maximum = np.max(avg_p)

plt.figure()
plt.plot(range_theta, avg_p)
plt.xlabel('Scattered Elevation Angle ($\degree$)', fontsize=12)
plt.ylabel('Mean Scattered Power (dB)', fontsize=12)
plt.title(f'Measured Power when Incident at {theta}$\degree$', fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=12)

plt.annotate(f'$\sigma$={sigma}mm', (theta_max-2.5,maximum-0.8), fontsize=10,color='black')
plt.annotate(f'{Stat_distribution}',(theta_max-2.5,maximum-0.3), fontsize=10,color='black')

#plt.savefig(f'../../Graphs/Experimental_scattering/{Stat_distribution}_{sigma}mm_{theta}_power_avg.png', dpi=1000)
# Out:
# [-40.849549493664995, -31.440174814038013, -36.31737761023386, -34.698716553258855, -42.30391555211434, -38.90846978038824, -37.92735436295338, -36.47818576889775, -35.66755682535354, -33.812051775930556, -37.68336108065228, -41.329850369307465, -38.053881827952516]
# Text(65.5, -31.740174814038014, 'Gaussian')
